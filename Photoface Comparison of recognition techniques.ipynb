# %% [markdown]
# ## Photoface DB usage with opencv examples
#
# #### Eigenfaces
#
# First, we will run the eigenfaces demo against the database and investigate the reconstruction of the image based on the number of eigenvectors

# %%
from IPython.display import HTML, display

display(Image(filename="/home/arthur/opencv/build/bin/test/eigenface_reconstruction_10.png", width=200))
display(Image(filename="/home/arthur/opencv/build/bin/test/eigenface_reconstruction_25.png", width=200))
display(Image(filename="/home/arthur/opencv/build/bin/test/eigenface_reconstruction_55.png", width=200))
display(Image(filename="/home/arthur/opencv/build/bin/test/eigenface_reconstruction_85.png", width=200))
display(Image(filename="/home/arthur/opencv/build/bin/test/eigenface_reconstruction_100.png", width=200))
display(Image(filename="/home/arthur/opencv/build/bin/test/eigenface_reconstruction_130.png", width=200))
